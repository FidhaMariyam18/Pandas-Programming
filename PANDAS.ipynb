# %% [markdown]
# <a href="https://colab.research.google.com/github/FidhaMariyam18/Pandas-Programming/blob/main/PANDAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
l=[1,2,3,4,5]
s=pd.Series(l)
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
l=[1,2,3]
s=pd.Series(l,index=['A','B','C'])
print(s)
# Out:
# A    1
# B    2
# C    3
# dtype: int64

# %%
data={'name':'rih','class':'BCA','age':18}
s=pd.Series(data)
print(s)
# Out:
# name     rih
# class    BCA
# age       18
# dtype: object

# %%
#LOC(does not skip end value bcz it is a character)
import pandas as pd
data=[10,20,30,40,50]
a=pd.Series(data,index=['A','B','C','D','E'])
print(a.loc['C'])
print(a.loc['B':'D'])
# Out:
# 30
# B    20
# C    30
# D    40
# dtype: int64

# %%
#ILOC(skip last value bcz it is a number)
data=[10,20,30]
a=pd.Series(data)
print(a.iloc[0])
print(a.iloc[:2])
# Out:
# 10
# 0    10
# 1    20
# dtype: int64

# %%
import pandas as pd
sales=pd.Series(
    [1200,850,1500,950,2000],
    index=['Monday','Tuesday','Wednesday','Thursday','Friday']
)
print(sales)
print(sales.max())
print(sales.min())
print(sales.sum())
print(sales[sales<1000])
# Out:
# Monday       1200
# Tuesday       850
# Wednesday    1500
# Thursday      950
# Friday       2000
# dtype: int64
# 2000
# 850
# 6500
# Tuesday     850
# Thursday    950
# dtype: int64

# %%
import pandas as pd
data=[20,20,30,40,90,60,60,60]
ar=pd.Series(data)
print(ar.unique())   #used to remove duplicate value
print(ar.nunique())   #count of unique number
print(ar.value_counts())  #to show how many times a number repeated
# Out:
# [20 30 40 90 60]
# 5
# 60    3
# 20    2
# 30    1
# 40    1
# 90    1
# Name: count, dtype: int64

# %%
data=[20,None,80,65,None,79,99]
ar=pd.Series(data)
print(ar.isna())  #show TRUE for none values
print(ar.notna())  #show FALSE for none values
print(ar.dropna())  #show values otherthan none values
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# 5    False
# 6    False
# dtype: bool
# 0     True
# 1    False
# 2     True
# 3     True
# 4    False
# 5     True
# 6     True
# dtype: bool
# 0    20.0
# 2    80.0
# 3    65.0
# 5    79.0
# 6    99.0
# dtype: float64
